# %% [markdown]
# # Q1- What is the difference between a function and a method in Python?
#
#
# In Python, the terms "function" and "method" refer to similar concepts, but there are key differences:
#
# Function:
#
# A function is a block of reusable code that performs a specific task. It can be defined using the def keyword and can be called independently.
# Functions can exist outside of any class.
#
# Example-

# %%
class Calculator:
    def __init__(self, value):
        self.value = value

    def add(self, x):
        self.value += x

calc = Calculator(10)  # Creating an instance
calc.add(5)            # Calling the method on the instance

# %% [markdown]
# # Q2- Explain the concept of function arguments and parameters in python.
#
#
# In Python, function arguments and parameters are crucial concepts for writing flexible and reusable code. Here's a detailed breakdown of both:
#
#
# Parameters Definition: Parameters are variables listed in a function’s definition. They act as placeholders for the values that will be passed to the function.
#
# Example-

# %%
def greet(name, age):  # 'name' and 'age' are parameters
    print(f"Hello {name}, you are {age} years old.")

# %% [markdown]
# Arguments Definition: Arguments are the actual values or data you pass to the function when calling it. They replace the parameters in the function's definition.
#
# Example-

# %%
greet("Alice", 30)  # "Alice" and 30 are arguments

# %% [markdown]
# # Q3- What are the different ways to define and call a fuction in python?
#
# Basic Function Definition and Call
# Definition: Defined using the def keyword.
# Call: Call the function by its name followed by parentheses.
#
# Example:

# %%
# Function definition
def greet(name):
    print(f"Hello, {name}!")

# Function call
greet("Alice")

# %% [markdown]
# # Q4- What is the purpose of the return statement in a pyhton function.
#
#
# The return statement in a Python function is essential for several reasons:
#
# 1. Returning a Value
# The primary purpose of the return statement is to send a result from the function back to the caller. This allows the function to produce an output that can be used elsewhere in the program.
#
# Example:

# %%
def add(a, b):
    return a + b

result = add(3, 5)  # The return value 8 is assigned to the variable 'result'
print(result)       # Outputs: 8

# %% [markdown]
# 2. Ending Function Execution
# When a return statement is encountered, the function execution terminates immediately, and control is passed back to the caller. Any code after the return statement in the function will not be executed.
#
# Example:

# %%
def demo(x):
    if x > 10:
        return "x is too large"
    print("x is within range")

result = demo(15)  # Outputs: "x is too large"

# %% [markdown]
# 3. Returning Multiple Values
# Python functions can return multiple values as a tuple. This is useful when you want to return several pieces of related information from a function.
#
# Example:

# %%
def get_statistics(numbers):
    mean = sum(numbers) / len(numbers)
    maximum = max(numbers)
    minimum = min(numbers)
    return mean, maximum, minimum

mean, max_value, min_value = get_statistics([1, 2, 3, 4, 5])
print(mean, max_value, min_value)  # Outputs: 3.0 5 1

# %% [markdown]
# 4. Returning None
# If a function does not explicitly use a return statement, or if the return statement does not include an expression, the function returns None by default. This is useful for functions that perform actions but do not need to return a value.
#
# Example:

# %%
def print_message(message):
    print(message)
    # No return statement, so the function returns None

result = print_message("Hello, World!")  # Outputs: "Hello, World!"
print(result)  # Outputs: None

# %% [markdown]
# # Q5- What are iterators in python and how do they differ from iterables?
#
# Iterables
# Definition: An iterable is any Python object capable of returning its members one at a time. It is an object that can be looped over (iterated over) using a for loop or comprehended using a comprehension. Common examples include lists, tuples, strings, and dictionaries.
#
# Characteristics:
#
# Definition: Iterables implement the __iter__() method, which returns an iterator object. Alternatively, they implement the __getitem__() method, which allows indexed access.
# Usage: You can iterate over an iterable using a for loop or pass it to functions like list(), set(), or sum().
#
# Example:

# %%
# List is an iterable
my_list = [1, 2, 3, 4, 5]

# You can iterate over the list
for item in my_list:
    print(item)

# %% [markdown]
# Iterators
# Definition: An iterator is an object that represents a stream of data. It produces items one at a time and maintains its state as it iterates. An iterator is an object that follows the iterator protocol: it implements the __iter__() and __next__() methods.
#
# Characteristics:
#
# Definition: Iterators implement the __iter__() method (which returns the iterator object itself) and the __next__() method (which returns the next item in the sequence). When there are no more items to return, __next__() raises the StopIteration exception to signal the end of iteration.
# Usage: You can use an iterator to traverse through all elements of an iterable one at a time, usually in a for loop or with the next() function.
#
# Example:

# %%
# Create an iterator from a list
my_list = [1, 2, 3, 4, 5]
iterator = iter(my_list)  # Get an iterator from the iterable

# Manually iterate over the iterator
print(next(iterator))  # Outputs: 1
print(next(iterator))  # Outputs: 2
# and so on...

# %% [markdown]
# # Q6- Explain the concepts of generators in python and how they are defined.
#
#
# A generator is a special type of iterator that is defined using a function but yields values one at a time, using the yield keyword. Generators are used to produce a sequence of values over time, rather than computing all the values upfront and storing them in memory. This can be particularly useful for working with large datasets or streams of data.
#
# Key Characteristics of Generators
# Lazy Evaluation:
#
# Generators produce items one at a time and only when required, which means they are more memory-efficient than using lists or other collections that require holding all values in memory.
# Stateful Iteration:
#
# Generators maintain their state between iterations. They remember where they left off and resume from that point when next() is called.
# Simplified Code:
#
# They allow you to write code that is more readable and concise compared to manually implementing an iterator class.
# Defining Generators
# Generators are defined using functions with the yield keyword. Unlike functions that return a single value and exit, generator functions can yield multiple values, pausing and resuming their execution.
#
# Example of a Generator Function:

# %%
def count_up_to(max):
    count = 1
    while count <= max:
        yield count
        count += 1

# Using the generator
counter = count_up_to(5)
for num in counter:
    print(num)  # Outputs: 1, 2, 3, 4, 5

# %% [markdown]
# # Q7- What are the advantages of using generators over regular functions?
#
# 1. Memory Efficiency
# Advantage: Generators are memory-efficient because they generate values one at a time and do not require the entire sequence to be stored in memory.
#
# Regular Functions: Typically return an entire list or collection, which can be memory-intensive for large datasets.
# Generators: Yield values on-the-fly, which means only one value is stored in memory at any given time.
#
# Example:

# %%
# Regular function (memory-intensive)
def generate_large_list(n):
    return [i for i in range(n)]

large_list = generate_large_list(10**6)  # Stores a large list in memory

# Generator (memory-efficient)
def generate_large_numbers(n):
    for i in range(n):
        yield i

large_generator = generate_large_numbers(10**6)  # Does not store values, generates on demand

# %% [markdown]
# 2. Performance Improvement
# Advantage: Generators can improve performance by producing values only when needed, reducing the initial computation time and avoiding the overhead of creating and storing large data structures.
#
# Regular Functions: Compute and return the entire result set in one go, which may be slow for large datasets.
# Generators: Compute values as needed, which can be faster and allows for more responsive and interactive applications.
#
# Example:

# %%
# Using a generator
def count_up_to(max):
    count = 1
    while count <= max:
        yield count
        count += 1

# Efficiently iterates over values without computing all at once
for num in count_up_to(10**6):
    pass  # Process numbers one by one

# %% [markdown]
# 3. Infinite Sequences
# Advantage: Generators can be used to create infinite sequences, something that is not feasible with regular functions that generate finite collections.
#
# Regular Functions: Cannot return infinite sequences because they require allocating memory for all elements.
# Generators: Can handle infinite sequences since they generate values on-the-fly.
#
# Example:

# %%
# Generator for an infinite sequence
def infinite_count(start=0):
    while True:
        yield start
        start += 1

for num in infinite_count():
    if num > 10:
        break  # Stop after a certain condition
    print(num)

# %% [markdown]
# 4. Lazy Evaluation
# Advantage: Generators use lazy evaluation, meaning they produce values only when required. This can lead to significant performance benefits when dealing with large datasets or streams of data.
#
# Regular Functions: Evaluate all values at once, even if only a subset is needed.
# Generators: Evaluate and yield values as needed, saving computation and memory.
#
# Example:

# %%
# Generator that reads lines from a file
def read_lines(file_name):
    with open(file_name, 'r') as file:
        for line in file:
            yield line

# Reads file line by line, only loading one line into memory at a time
for line in read_lines('large_file.txt'):
    process(line)  # Process each line as it is read

# %% [markdown]
# 5. Simplified Code
# Advantage: Generators can simplify code by eliminating the need for explicit iterator classes and maintaining state between iterations.
#
# Regular Functions: May require additional code to manage state and iteration logic.
# Generators: Use yield to manage iteration and state concisely within a single function.
#
# Example:

# %%
# Regular function with explicit iterator class
class Counter:
    def __init__(self, low, high):
        self.current = low
        self.high = high

    def __iter__(self):
        return self

    def __next__(self):
        if self.current > self.high:
            raise StopIteration
        self.current += 1
        return self.current - 1

# Simplified with a generator
def counter(low, high):
    while low <= high:
        yield low
        low += 1

# %% [markdown]
# # Q8. What is a lambda function in Python and when is it typically used?
#
# A lambda function in Python is a small, anonymous function defined using the lambda keyword. It is designed to be concise and is typically used for short-lived operations where a full function definition might be overkill. Lambda functions are especially useful for creating quick, throwaway functions on the fly.
#
# Syntax and Definition
# The syntax for a lambda function is:
#
# python
# Copy code
# lambda arguments: expression
# lambda: The keyword used to define a lambda function.
# arguments: A comma-separated list of parameters.
# expression: A single expression that is evaluated and returned. Lambda functions cannot contain multiple expressions or statements.
#
# Example:

# %%
# A simple lambda function that adds two numbers
add = lambda x, y: x + y

# Using the lambda function
result = add(3, 5)
print(result)  # Outputs: 8

# %% [markdown]
# # Q9- Explain the purpose and usage of the `map()` function in Python.
#
# The map() function in Python is a built-in function that applies a given function to each item in an iterable (such as a list or tuple) and returns an iterator that produces the results. It is a part of Python's functional programming tools and is often used to perform operations on each element of an iterable without using an explicit loop.
#
# Purpose of map()
# The primary purpose of the map() function is to simplify the process of applying a transformation or operation to each element of an iterable. It helps to keep code clean and readable by eliminating the need for explicit loops.
#
# Syntax
# python
# Copy code
# map(function, iterable, ...)
# function: A function that takes one or more arguments and returns a result. This function is applied to each item in the iterable.
# iterable: An iterable (e.g., list, tuple) whose elements will be processed by the function.
# ...: Additional iterables (optional). If multiple iterables are passed, the function must accept as many arguments as there are iterables.
#
# Example:

# %%
def square(x):
    return x * x

numbers = [1, 2, 3, 4, 5]
squared_numbers = map(square, numbers)
print(list(squared_numbers))  # Outputs: [1, 4, 9, 16, 25]

# %% [markdown]
# # Q10- What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#
# The map(), reduce(), and filter() functions in Python are all functional programming tools used to process iterables. While they share similarities in their purpose—transforming and processing data—each has distinct functionality and use cases.
#
# 1. map()
# Purpose: Applies a function to each item in an iterable (or iterables) and returns an iterator of the results.
#
# Syntax:
#
# map(function, iterable, ...)
# function: A function that takes one or more arguments and returns a result.
# iterable: An iterable whose elements will be processed by the function.
# ...: Additional iterables (optional). The function must accept as many arguments as there are iterables.
# Characteristics:
#
# Transforms each element in the iterable(s) based on the function provided.
# Returns an iterator of the transformed values.
#
# Example:

# %%
numbers = [1, 2, 3, 4, 5]
squared = map(lambda x: x ** 2, numbers)
print(list(squared))  # Outputs: [1, 4, 9, 16, 25]

# %% [markdown]
# 2. reduce()
# Purpose: Applies a function of two arguments cumulatively to the items of an iterable, from left to right, to reduce the iterable to a single value.
#
# Syntax:
#
#
# from functools import reduce
# reduce(function, iterable[, initializer])
# function: A function that takes two arguments and returns a single value.
# iterable: An iterable whose elements will be reduced.
# initializer: (Optional) An initial value to start the reduction.
# Characteristics:
#
# Reduces the iterable to a single value by applying the function cumulatively.
# reduce() requires importing from the functools module.
#
# Example:

# %%
from functools import reduce

numbers = [1, 2, 3, 4, 5]
product = reduce(lambda x, y: x * y, numbers)
print(product)  # Outputs: 120

# %% [markdown]
# 3. filter()
# Purpose: Filters elements of an iterable based on a function that returns True or False, and returns an iterator of the elements that satisfy the condition.
#
# Syntax:
#
#
# filter(function, iterable)
# function: A function that takes one argument and returns True or False.
# iterable: An iterable whose elements will be filtered.
# Characteristics:
#
# Selects elements from the iterable based on the function’s return value (True or False).
# Returns an iterator of the filtered values.
#
# Example:

# %%
numbers = [1, 2, 3, 4, 5]
even_numbers = filter(lambda x: x % 2 == 0, numbers)
print(list(even_numbers))  # Outputs: [2, 4]

# %% [markdown]
# #Q11- Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13];

# %% [markdown]
# ![compressed_image 12345 (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Pratical questions:-

# %% [markdown]
# # Q1- Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
# the list.
#
# Certainly! To create a Python function that sums all the even numbers in a given list, you can follow these steps:
#
# Iterate through the list of numbers.
# Check if each number is even.
# If the number is even, add it to a running total.
# Return the total sum of even numbers.
# Here’s a Python function that accomplishes this:

# %%
def sum_of_even_numbers(numbers):
    # Initialize the sum variable
    total_sum = 0

    # Iterate through the list
    for number in numbers:
        # Check if the number is even
        if number % 2 == 0:
            # Add the even number to the total sum
            total_sum += number

    # Return the total sum of even numbers
    return total_sum

# Example usage
numbers = [47, 11, 42, 13]
print(sum_of_even_numbers(numbers))  # Output: 42

# %% [markdown]
# # Q2- Create a Python function that accepts a string and returns the reverse of that string.
#
# Certainly! To create a Python function that reverses a given string, you can use Python's slicing feature, which provides a concise and efficient way to reverse a string. Here's how you can write such a function:

# %%
def reverse_string(s):
    # Return the reversed string using slicing
    return s[::-1]

# Example usage
input_string = "hello"
print(reverse_string(input_string))  # Output: "olleh"

# %% [markdown]
# Explanation
# Function Definition: def reverse_string(s): defines a function named reverse_string that takes a single parameter s, which is the input string.
#
# Reversing the String: The expression s[::-1] uses slicing to reverse the string.
#
# s[start:end:step] is the slicing syntax.
# By omitting start and end, and using -1 as the step, you effectively reverse the string.
# s[::-1] means "start from the end of the string and step backwards to the beginning."
# Return Result: The function returns the reversed string.

# %% [markdown]
# # Q3- Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.
#
# Certainly! To implement a Python function that takes a list of integers and returns a new list containing the squares of each number, you can use list comprehension, which provides a concise and efficient way to transform lists. Here's how you can do it:

# %%
def squares_of_numbers(numbers):
    # Create a new list with squares of each number using list comprehension
    return [x ** 2 for x in numbers]

# Example usage
input_list = [1, 2, 3, 4, 5]
print(squares_of_numbers(input_list))  # Output: [1, 4, 9, 16, 25]

# %% [markdown]
# Explanation
# Function Definition: def squares_of_numbers(numbers): defines a function named squares_of_numbers that takes a parameter numbers, which is expected to be a list of integers.
#
# List Comprehension: [x ** 2 for x in numbers] creates a new list:
#
# x ** 2 calculates the square of each number x in the input list.
# for x in numbers iterates over each element in the numbers list.
# The result is a new list where each element is the square of the corresponding element in the input list.
# Return Result: The function returns the new list of squared numbers.

# %% [markdown]
# # Q4- Write a Python function that checks if a given number is prime or not from 1 to 200.
#
# To write a Python function that checks if a given number is prime and also ensure that it only works for numbers between 1 and 200, you need to:
#
# Check if the number is within the valid range (1 to 200).
# Determine if the number is a prime number.
# A prime number is a number greater than 1 that has no positive divisors other than 1 and itself.
#
# Here’s how you can implement such a function:

# %%
def is_prime(number):
    # Check if the number is within the valid range
    if number < 1 or number > 200:
        return False

    # 1 and numbers less than 1 are not prime
    if number <= 1:
        return False

    # Check for factors from 2 up to the square root of the number
    for i in range(2, int(number**0.5) + 1):
        if number % i == 0:
            return False

    return True

# Example usage
test_numbers = [1, 2, 3, 4, 5, 200, 199, 101]
results = {num: is_prime(num) for num in test_numbers}
print(results)

# %% [markdown]
# Explanation
# Range Check: The function first checks if the number is within the range [1, 200]. If not, it returns False.
#
# Prime Check:
#
# Numbers less than or equal to 1 are not prime.
# For numbers greater than 1, the function checks divisibility from 2 up to the square root of the number (rounded down) using int(number**0.5) + 1. This is because a larger factor of the number would have to be paired with a smaller factor that would have already been checked.
# If any number divides number evenly (i.e., number % i == 0), then number is not prime.
# Return Result: If no divisors are found, the number is prime, and the function returns True.

# %% [markdown]
# # Q5- Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.
#
# To create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms, you'll need to define a class with the necessary methods to support iteration. The key components are:
#
# Initialization: The class should accept the number of terms to generate.
# Iterator Methods: Implement __iter__() and __next__() methods to make the class an iterator.
#
# Here’s a step-by-step implementation:

# %%
class FibonacciIterator:
    def __init__(self, n):
        """Initialize with the number of terms."""
        self.n = n
        self.current = 0
        self.a, self.b = 0, 1

    def __iter__(self):
        """Return the iterator object itself."""
        return self

    def __next__(self):
        """Return the next value in the Fibonacci sequence."""
        if self.current < self.n:
            # The current value in the sequence
            result = self.a
            # Update Fibonacci numbers
            self.a, self.b = self.b, self.a + self.b
            self.current += 1
            return result
        else:
            # Stop iteration if n terms have been generated
            raise StopIteration

# Example usage
fibonacci_sequence = FibonacciIterator(10)
for number in fibonacci_sequence:
    print(number)

# %% [markdown]
# Explanation
# Initialization (__init__):
#
# self.n: Stores the total number of terms to generate.
# self.current: Keeps track of the number of terms generated so far.
# self.a and self.b: Initialize the first two Fibonacci numbers (0 and 1).
# Iterator Method (__iter__):
#
# Returns the iterator object itself. This is required for the iterator protocol.
# Next Value Method (__next__):
#
# Checks if the number of terms generated (self.current) is less than the specified number (self.n).
# If true, returns the current Fibonacci number (self.a) and updates self.a and self.b to the next values in the sequence.
# If the number of terms generated is equal to or greater than self.n, it raises StopIteration to signal that the iteration is complete.

# %% [markdown]
# # Q6- Write a generator function in Python that yields the powers of 2 up to a given exponent.
#
# Certainly! A generator function in Python provides a way to iterate over a sequence of values without generating the entire sequence at once. To create a generator that yields the powers of 2 up to a given exponent, you can use the yield keyword.
#
# Here’s how you can write such a generator function:

# %%
def powers_of_two(max_exponent):
    """Generator that yields powers of 2 up to 2^max_exponent."""
    exponent = 0
    while exponent <= max_exponent:
        yield 2 ** exponent
        exponent += 1

# Example usage
for power in powers_of_two(5):
    print(power)

# %% [markdown]
# This function, powers_of_two, takes a max_exponent as an argument and yields 2 raised to each exponent from 0 to max_exponent. You can call it and iterate through the results to see the powers of 2.

# %% [markdown]
# #Q7- Implement a generator function that reads a file line by line and yields each line as a string.

# %% [markdown]
# You can create a generator function that reads a file line by line and yields each line as a string using the following code:

# %%
def read_file_line_by_line(file_path):
    with open(file_path, 'r') as file:
        for line in file:
            yield line.strip()  # strip() removes any leading/trailing whitespace

# Example usage:
# for line in read_file_line_by_line('example.txt'):
#     print(line)

# %% [markdown]
# This read_file_line_by_line function opens the specified file and iterates through each line, yielding the stripped line. You can call this generator and iterate over it to process each line of the file one at a time.

# %% [markdown]
# #Q8- Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

# %% [markdown]
# You can use a lambda function to sort a list of tuples based on the second element of each tuple like this:

# %%
# Sample list of tuples
data = [(1, 'apple'), (2, 'orange'), (3, 'banana'), (4, 'grape')]

# Sort the list based on the second element of each tuple
sorted_data = sorted(data, key=lambda x: x[1])

# Example usage
print(sorted_data)

# %% [markdown]
# In this code, sorted() is used to sort the data list, and the key parameter is set to a lambda function that takes a tuple x and returns its second element (x[1]). The result will be a list of tuples sorted alphabetically by the second element.

# %% [markdown]
# # Q9- Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit

# %% [markdown]
# You can use the map() function to convert a list of temperatures from Celsius to Fahrenheit with the following program:

# %%
# List of temperatures in Celsius
celsius_temps = [0, 20, 37, 100]

# Function to convert Celsius to Fahrenheit
def celsius_to_fahrenheit(celsius):
    return (celsius * 9/5) + 32

# Use map to convert Celsius to Fahrenheit
fahrenheit_temps = list(map(celsius_to_fahrenheit, celsius_temps))

# Example usage
print(fahrenheit_temps)

# %% [markdown]
# In this code, the celsius_to_fahrenheit function performs the conversion, and map() applies this function to each element in the celsius_temps list. The result is then converted to a list and printed out.

# %% [markdown]
# #Q10- Create a Python program that uses `filter()` to remove all the vowels from a given string.

# %% [markdown]
# You can create a Python program that uses the filter() function to remove all vowels from a given string. Here's a simple implementation:

# %%
def remove_vowels(input_string):
    # Define a set of vowels
    vowels = set('aeiouAEIOU')

    # Use filter to remove vowels
    filtered_string = ''.join(filter(lambda char: char not in vowels, input_string))

    return filtered_string

# Example usage
input_string = "Hello, World!"
result = remove_vowels(input_string)
print(result)  # Output: Hll, Wrld!

# %% [markdown]
# Explanation:
# Vowels Set: A set of vowels (both lowercase and uppercase) is defined.
# Filter Function: The filter() function is used with a lambda function that checks if each character is not in the vowels set.
# Join: The resulting filtered characters are joined back into a string using join().
# Example Usage: The program demonstrates how to call the function and prints the result.
# Feel free to modify the input_string variable to test with different strings!

# %% [markdown]
# #Q11- Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:
#
# Order Number      Book Tittle and Order           Quantity     price per item
# 34587             Learning python, Mark lutz           4              40.95
# 38762             progrmming pyhton, Mark lutz         5              56.80
# 77226             head first python, paul beery        3              32.95
# 88112             Einfuhrung in python3, bernd klein   3              24.95
#
# Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
# product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
# order is smaller than 100,00 €.
#
# Write a Python program using lambda and map.

# %% [markdown]
# Certainly! You can achieve this using Python's map function along with a lambda to create the desired list of 2-tuples. Below is a sample implementation that calculates the total value for each order based on the conditions you specified:

# %%
# Define the list of orders
orders = [
    [34587, "Learning python, Mark Lutz", 4, 40.95],
    [38762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.95]
]

# Function to calculate the order totals
def calculate_totals(order):
    order_number = order[0]
    quantity = order[2]
    price_per_item = order[3]
    total_value = quantity * price_per_item

    # Increase total by 10 if it's less than 100
    if total_value < 100:
        total_value += 10

    return (order_number, total_value)

# Use map and lambda to apply the function to the orders
result = list(map(lambda order: calculate_totals(order), orders))

# Print the result
print(result)

# %% [markdown]
# Certainly! You can achieve this using Python's map function along with a lambda to create the desired list of 2-tuples. Below is a sample implementation that calculates the total value for each order based on the conditions you specified:
#
# python
# Copy code
# # Define the list of orders
# orders = [
#     [34587, "Learning python, Mark Lutz", 4, 40.95],
#     [38762, "Programming Python, Mark Lutz", 5, 56.80],
#     [77226, "Head First Python, Paul Barry", 3, 32.95],
#     [88112, "Einführung in Python3, Bernd Klein", 3, 24.95]
# ]
#
# # Function to calculate the order totals
# def calculate_totals(order):
#     order_number = order[0]
#     quantity = order[2]
#     price_per_item = order[3]
#     total_value = quantity * price_per_item
#
#     # Increase total by 10 if it's less than 100
#     if total_value < 100:
#         total_value += 10
#
#     return (order_number, total_value)
#
# # Use map and lambda to apply the function to the orders
# result = list(map(lambda order: calculate_totals(order), orders))
#
# # Print the result
# print(result)
# Explanation:
# Data Structure: The orders are stored as a list of lists, where each inner list contains the order number, title, quantity, and price per item.
# Function: The calculate_totals function computes the total for each order, applying the additional fee condition.
# Mapping: The map function applies the calculate_totals function to each order in the orders list.
# Result: Finally, the results are converted to a list and printed.
# When you run this code, it will produce a list of tuples with the order number and the corresponding total value.
